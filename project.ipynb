# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib

# %%
data=pd.read_csv('Data.csv')
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
data2=data.drop(['availability','society','area_type','balcony'],axis='columns')
data2.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
data2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
data3=data2.dropna()
data3.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
data3.shape
# Out:
# (13246, 5)

# %%
data3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
data3['BHK']=data3['size'].apply(lambda x: int(x.split(' ')[0]))
data3
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_19388\193927209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['BHK']=data3['size'].apply(lambda x: int(x.split(' ')[0]))
#                        location       size total_sqft  bath   price  BHK
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# ...

# %%
data3['BHK'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
data3[data3.BHK>20]
# Out:
#                        location        size total_sqft  bath  price  BHK
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0   27
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0   43

# %%
data3.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def float_number(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
data3[~data3['total_sqft'].apply(float_number)]
# Out:
#                  location   size   total_sqft  bath    price  BHK
# 30              Yelahanka  4 BHK  2100 - 2850   4.0  186.000    4
# 122                Hebbal  4 BHK  3067 - 8156   4.0  477.000    4
# 137    8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   54.005    2
# 165              Sarjapur  2 BHK  1145 - 1340   2.0   43.490    2
# 188              KR Puram  2 BHK  1015 - 1540   2.0   56.800    2
# ...                   ...    ...          ...   ...      ...  ...
# 12975          Whitefield  2 BHK   850 - 1060   2.0   38.190    2
# 12990      Talaghattapura  3 BHK  1804 - 2273   3.0  122.000    3
# 13059              Harlur  2 BHK  1200 - 1470   2.0   72.760    2
# 13265               Hoodi  2 BHK  1133 - 1384   2.0   59.135    2
# 13299          Whitefield  4 BHK  2830 - 2882   5.0  154.500    4
#
# [190 rows x 6 columns]

# %%
data3[~data3['total_sqft'].apply(float_number)].head(10)
# Out:
#                location       size      total_sqft  bath    price  BHK
# 30            Yelahanka      4 BHK     2100 - 2850   4.0  186.000    4
# 122              Hebbal      4 BHK     3067 - 8156   4.0  477.000    4
# 137  8th Phase JP Nagar      2 BHK     1042 - 1105   2.0   54.005    2
# 165            Sarjapur      2 BHK     1145 - 1340   2.0   43.490    2
# 188            KR Puram      2 BHK     1015 - 1540   2.0   56.800    2
# 410             Kengeri      1 BHK  34.46Sq. Meter   1.0   18.500    1
# 549         Hennur Road      2 BHK     1195 - 1440   2.0   63.770    2
# 648             Arekere  9 Bedroom       4125Perch   9.0  265.000    9
# 661           Yelahanka      2 BHK     1120 - 1145   2.0   48.130    2
# 672        Bettahalsoor  4 Bedroom     3090 - 5002   4.0  445.000    4

# %%
def average_sqft(x):
    feet=x.split('-')
    if len(feet)==2:
        return (float(feet[0])+float(feet[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
data4=data3.copy()
data4['total_sqft']= data4['total_sqft'].apply(average_sqft)
data4
# Out:
#                        location       size  total_sqft  bath   price  BHK
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316             Richards Town      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
data4.loc[30]
# Out:
# location      Yelahanka
# size              4 BHK
# total_sqft       2475.0
# bath                4.0
# price             186.0
# BHK                   4
# Name: 30, dtype: object

# %%
data5=data4.copy()
data5['price_per_sqft']=(data5['price']*100000)/data5['total_sqft']
data5
# Out:
#                        location       size  total_sqft  bath   price  BHK  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316             Richards Town      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# ...

# %%
len(data5['location'].unique())
# Out:
# 1304

# %%
data5['location']=data5['location'].apply(lambda x:x.strip())
loc_stats=data5.groupby('location')['location'].agg('count').sort_values(ascending=False)
loc_stats
# Out:
# location
# Whitefield               535
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           266
# Thanisandra              236
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Karnataka Shabarimala      1
# whitefiled                 1
# Name: location, Length: 1293, dtype: int64

# %%
loc_stats_less_than_10=loc_stats[loc_stats<=10]
loc_stats_less_than_10
# Out:
# location
# Basapura                 10
# 1st Block Koramangala    10
# Gunjur Palya             10
# Kalkere                  10
# Sector 1 HSR Layout      10
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Karnataka Shabarimala     1
# whitefiled                1
# Name: location, Length: 1052, dtype: int64

# %%
len(data5['location'].unique())
# Out:
# 1293

# %%
data5['location']=data5['location'].apply(lambda x: 'not_require' if x in loc_stats_less_than_10 else x)
len(data5['location'].unique())
# Out:
# 242

# %%
data5.head(20)
# Out:
#                     location       size  total_sqft  bath   price  BHK  \
# 0   Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1           Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3         Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                   Kothanur      2 BHK      1200.0   2.0   51.00    2
# 5                 Whitefield      2 BHK      1170.0   2.0   38.00    2
# 6           Old Airport Road      4 BHK      2732.0   4.0  204.00    4
# 7               Rajaji Nagar      4 BHK      3300.0   4.0  600.00    4
# 8               Marathahalli      3 BHK      1310.0   3.0   63.25    3
# 9                not_require  6 Bedroom      1020.0   6.0  370.00    6
# 10                Whitefield      3 BHK      1800.0   2.0   70.00    3
# 11                Whitefield  4 Bedroom      2785.0   5.0  295.00    4
# ...

# %%
data5[data5['total_sqft']/data5['BHK']<300]
# Out:
#                   location       size  total_sqft  bath  price  BHK  \
# 9              not_require  6 Bedroom      1020.0   6.0  370.0    6
# 45              HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 58           Murugeshpalya  6 Bedroom      1407.0   4.0  150.0    6
# 68     Devarachikkanahalli  8 Bedroom      1350.0   7.0   85.0    8
# 70             not_require  3 Bedroom       500.0   3.0  100.0    3
# ...                    ...        ...         ...   ...    ...  ...
# 13277          not_require  7 Bedroom      1400.0   7.0  218.0    7
# 13279          not_require  6 Bedroom      1200.0   5.0  130.0    6
# 13281      Margondanahalli  5 Bedroom      1375.0   5.0  125.0    5
# 13303       Vidyaranyapura  5 Bedroom       774.0   5.0   70.0    5
# 13311     Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
#
#        price_per_sqft
# 9        36274.509804
# 45       33333.333333
# 58       10660.980810
# 68        6296.296296
# 70       20000.000000
# ...

# %%
data5.shape
# Out:
# (13246, 7)

# %%
data6= data5[~(data5['total_sqft']/data5['BHK']<300)]
data6
# Out:
#                        location       size  total_sqft  bath   price  BHK  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316               not_require      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# ...

# %%
data6.shape
# Out:
# (12502, 7)

# %%
data6['price_per_sqft'].describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def remove_ppf_outliers(df):
    df_out=pd.DataFrame()
    for key, subdf in df.groupby('location'):
        mean=np.mean(subdf.price_per_sqft)
        std=np.std(subdf.price_per_sqft)
        reduced_df=subdf[(subdf.price_per_sqft>(mean-std)) & (subdf.price_per_sqft<=(mean+std))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %%
data7=remove_ppf_outliers(data6)
data7.shape
# Out:
# (10241, 7)

# %%
data7['price_per_sqft'].describe()
# Out:
# count    10241.000000
# mean      5657.702572
# std       2266.476980
# min       1250.000000
# 25%       4244.762955
# 50%       5172.413793
# 75%       6426.099852
# max      24509.803922
# Name: price_per_sqft, dtype: float64

# %%
def plot_scatter_chart(df,location):
    bhk2=df[(df['location']==location) & (df['BHK']==2)]
    bhk3=df[(df['location']==location) & (df['BHK']==3)]
    matplotlib.rcParams['figure.figsize']=(15,10)
    plt.scatter(bhk2['total_sqft'],bhk2['price'],color='blue',label='2 BHK',s=50)
    plt.scatter(bhk3['total_sqft'],bhk3['price'],marker='+',color='green',label='3 BHK',s=50)
    plt.xlabel('Total Square Feet Area')
    plt.ylabel('Price Per Square Feet')
    plt.title(location)
    plt.legend()
# plot_scatter_chart(data7,'Rajaji Nagar')
plot_scatter_chart(data7,'Hebbal')

# %%
def remove_bhk_outliers(df):
    exclude_one=np.array([])
    for location,location_df in df.groupby('location'):
        bhk_stats={}
        for bhk,bhk_df in location_df.groupby('BHK'):
            bhk_stats[bhk]={
                'mean':np.mean(bhk_df['price_per_sqft']),
                'std':np.std(bhk_df['price_per_sqft']),
                'count':bhk_df.shape[0]
            }
        for bhk,bhk_df in location_df.groupby('BHK'):
            stats=bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_one=np.append(exclude_one,bhk_df[bhk_df['price_per_sqft']<(stats['mean'])].index.values)
    return df.drop(exclude_one,axis='index')
data8= remove_bhk_outliers(data7)
data8.shape
# Out:
# (7329, 7)

# %%
plot_scatter_chart(data8,'Hebbal')

# %%
plt.hist(data8['price_per_sqft'],rwidth=0.8)
plt.xlabel('Price Per Square Feet')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
data8['bath'].unique()
# Out:
# array([ 4.,  3.,  2.,  5.,  8.,  1.,  6.,  7.,  9., 12., 16., 13.])

# %%
data8[data8['bath']>10]
# Out:
#             location    size  total_sqft  bath  price  BHK  price_per_sqft
# 5277  Neeladri Nagar  10 BHK      4000.0  12.0  160.0   10     4000.000000
# 8486     not_require  10 BHK     12000.0  12.0  525.0   10     4375.000000
# 8575     not_require  16 BHK     10000.0  16.0  550.0   16     5500.000000
# 9308     not_require  11 BHK      6000.0  12.0  150.0   11     2500.000000
# 9639     not_require  13 BHK      5425.0  13.0  275.0   13     5069.124424

# %%
data9=data8[data8['bath']<data8['BHK']+2]
data9.shape
# Out:
# (7251, 7)

# %%
data10=data9.drop(['price_per_sqft','size'],axis='columns')
data10.shape
# Out:
# (7251, 5)

# %%
dummies=pd.get_dummies(data10['location'])
dummies
# Out:
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                     True               False                      False
# 1                     True               False                      False
# 2                     True               False                      False
# 3                     True               False                      False
# 4                     True               False                      False
# ...                    ...                 ...                        ...
# 10232                False               False                      False
# 10233                False               False                      False
# 10236                False               False                      False
# 10237                False               False                      False
# 10240                False               False                      False
#
#        2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# ...

# %%
data11=pd.concat([data10,dummies.drop('not_require',axis='columns')],axis='columns')
data11
# Out:
#                   location  total_sqft  bath  price  BHK  1st Block Jayanagar  \
# 0      1st Block Jayanagar      2850.0   4.0  428.0    4                 True
# 1      1st Block Jayanagar      1630.0   3.0  194.0    3                 True
# 2      1st Block Jayanagar      1875.0   2.0  235.0    3                 True
# 3      1st Block Jayanagar      1200.0   2.0  130.0    3                 True
# 4      1st Block Jayanagar      1235.0   2.0  148.0    2                 True
# ...                    ...         ...   ...    ...  ...                  ...
# 10232          not_require      1200.0   2.0   70.0    2                False
# 10233          not_require      1800.0   1.0  200.0    1                False
# 10236          not_require      1353.0   2.0  110.0    2                False
# 10237          not_require       812.0   1.0   26.0    1                False
# 10240          not_require      3600.0   5.0  400.0    4                False
#
# ...

# %%
data12=data11.drop('location',axis='columns')
data12
# Out:
#        total_sqft  bath  price  BHK  1st Block Jayanagar  1st Phase JP Nagar  \
# 0          2850.0   4.0  428.0    4                 True               False
# 1          1630.0   3.0  194.0    3                 True               False
# 2          1875.0   2.0  235.0    3                 True               False
# 3          1200.0   2.0  130.0    3                 True               False
# 4          1235.0   2.0  148.0    2                 True               False
# ...           ...   ...    ...  ...                  ...                 ...
# 10232      1200.0   2.0   70.0    2                False               False
# 10233      1800.0   1.0  200.0    1                False               False
# 10236      1353.0   2.0  110.0    2                False               False
# 10237       812.0   1.0   26.0    1                False               False
# 10240      3600.0   5.0  400.0    4                False               False
#
# ...

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
x=data12.drop('price',axis='columns')
x
# Out:
#        total_sqft  bath  BHK  1st Block Jayanagar  1st Phase JP Nagar  \
# 0          2850.0   4.0    4                 True               False
# 1          1630.0   3.0    3                 True               False
# 2          1875.0   2.0    3                 True               False
# 3          1200.0   2.0    3                 True               False
# 4          1235.0   2.0    2                 True               False
# ...           ...   ...  ...                  ...                 ...
# 10232      1200.0   2.0    2                False               False
# 10233      1800.0   1.0    1                False               False
# 10236      1353.0   2.0    2                False               False
# 10237       812.0   1.0    1                False               False
# 10240      3600.0   5.0    4                False               False
#
#        2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# ...

# %%
y=data12['price']
y
# Out:
# 0        428.0
# 1        194.0
# 2        235.0
# 3        130.0
# 4        148.0
#          ...
# 10232     70.0
# 10233    200.0
# 10236    110.0
# 10237     26.0
# 10240    400.0
# Name: price, Length: 7251, dtype: float64

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.2,random_state=10)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5800, 244)
# (1451, 244)
# (5800,)
# (1451,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
ypred=lr.predict(x_test)
ypred
# Out:
# array([70.47896311, 33.09312356, 36.00433051, ..., 29.45805298,
#        58.43306285, 68.60105208])

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(ypred,y_test))
# Out:
# 783.2659935249981

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
cross_val_score(LinearRegression(),x,y,cv=cv)
# Out:
# array([0.82430186, 0.77166234, 0.85089567, 0.80837764, 0.83653286])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def best_model(x,y):
    algorithms={'linear_regression':{
        'model':LinearRegression(),
        'params':{
            'positive':[True, False]
        }
    },
    'lasso':
    {
        'model':Lasso(),
        'params':{
            'alpha':[1,2],
            'selection':['random','cyclic']
        }
    },
    'decision_tree':
    {
        'model':DecisionTreeRegressor(),
        'params':{
            'criterion':['mse','friedman_mse'],
            'splitter':['best','random']
        }
    }
    }
    scores=[]
    cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name,config in algorithms.items():
        gs=GridSearchCV(config['model'],config['params'],cv=cv,return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model':algo_name,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])
best_model(x,y)
# Out:
# C:\Users\shlok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\shlok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
def prediction_of_price(location,sqft,bath,BHK):
    global x
    result1=[]
    location_index=np.where(x.columns==location)[0][0]
    X=np.zeros(len(x.columns))
    X[0]= sqft
    X[1]= bath
    X[2]= BHK
    if location_index>=0:
        X[location_index]=1
    result= lr.predict([X])[0]
    result1=result.split('.')
    print(result1[0])

# %%
df=pd.DataFrame(x)
df
df.to_csv('cleanx.csv')

# %%
location_index=np.where(x.columns=='Whitefield')[0][0]
location_index
# Out:
# 238

# %%
prediction_of_price('1st Phase JP Nagar',1000,2,2)
# Out:
# C:\Users\shlok\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\shlok\OneDrive\Desktop\PythonIndividual\project.ipynb Cell 56 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shlok/OneDrive/Desktop/PythonIndividual/project.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> prediction_of_price('1st Phase JP Nagar',1000,2,2)
#
# c:\Users\shlok\OneDrive\Desktop\PythonIndividual\project.ipynb Cell 56 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/shlok/OneDrive/Desktop/PythonIndividual/project.ipynb#Y106sZmlsZQ%3D%3D?line=9'>10</a>     X[location_index]=1
# ...

# %%
from joblib import dump

dump(lr,'./project/savedModels/model.joblib')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\shlok\OneDrive\Desktop\PythonIndividual\project.ipynb Cell 57 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/shlok/OneDrive/Desktop/PythonIndividual/project.ipynb#Y110sZmlsZQ%3D%3D?line=0'>1</a> from joblib import dump
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shlok/OneDrive/Desktop/PythonIndividual/project.ipynb#Y110sZmlsZQ%3D%3D?line=2'>3</a> dump(lr,'./project/savedModels/model.joblib')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
# ...
